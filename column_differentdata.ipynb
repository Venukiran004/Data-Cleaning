# %% [markdown]
# # Columms  having differnt formats

# %%
import pandas as pd

# %%
bed_room={"bhk":["2 BHK","3 Bedroom","2 bhk"]}

# %%
my_data=pd.DataFrame(bed_room)

# %%
my_data
# Out:
#          bhk
# 0      2 BHK
# 1  3 Bedroom
# 2      2 bhk

# %%
lit=[]

# %%
for i in range(0,3):
    ouput=my_data["bhk"][i].split(' ')
    lit.append(ouput[0])

# %%
lit
# Out:
# ['2', '3', '2']

# %%
my_data["no of Bedrooms"]=lit

# %%
my_data
# Out:
#          bhk no of Bedrooms
# 0      2 BHK              2
# 1  3 Bedroom              3
# 2      2 bhk              2

# %%
house={"bedroom":["2 BHK","2 bHK","2 bhk"]}

# %%
house_data=pd.DataFrame(house)

# %%
house_data
# Out:
#   bedroom
# 0   2 BHK
# 1   2 bHK
# 2   2 bhk

# %%
bedroom_list=[]
for i in range(0,3):
    bedroom=house_data["bedroom"][i].upper()  #lower
    bedroom_list.append(bedroom)

# %%
bedroom_list
# Out:
# ['2 BHK', '2 BHK', '2 BHK']

# %%
data_scientist=pd.read_csv(r"C:\Users\venuk\OneDrive\Desktop\assignment\DataScientist.csv")

# %%
data_scientist.head()
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
#
# ...

# %%
data_scientist["Salary Estimate"].value_counts()
# Out:
# $93K-$151K (Glassdoor est.)         62
# $113K-$180K (Glassdoor est.)        61
# $111K-$175K (Glassdoor est.)        60
# $71K-$122K (Glassdoor est.)         60
# $119K-$147K (Glassdoor est.)        44
#                                     ..
# $114K-$185K (Glassdoor est.)         7
# $99K-$173K (Glassdoor est.)          6
# $146K-$175K (Glassdoor est.)         3
# $10-$26 Per Hour(Glassdoor est.)     3
# $41K-$74K (Glassdoor est.)           1
# Name: Salary Estimate, Length: 148, dtype: int64

# %%
filter=[]
for i in range(0,3909):
    output=data_scientist["Salary Estimate"][i].split('(',1)
    filter.append(output[0])

# %%
filter[1:5]      #removed (GlassDoor est.)
# Out:
# ['$111K-$181K ', '$111K-$181K ', '$111K-$181K ', '$111K-$181K ']

# %%
data_scientist["filter_salary"]=filter

# %%
data_scientist.head()
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
#
# ...

# %%
##Per Hour

# %%
filter_1=[]
for i in range(0,3909):
    output=data_scientist["filter_salary"][i].replace('Per Hour',"")
    filter_1.append(output)

# %%
filter_1[:5]
# Out:
# ['$111K-$181K ',
#  '$111K-$181K ',
#  '$111K-$181K ',
#  '$111K-$181K ',
#  '$111K-$181K ']

# %%
data_scientist["filter_salary"]=filter_1
data_scientist["filter_salary"].head()
# Out:
# 0    $111K-$181K
# 1    $111K-$181K
# 2    $111K-$181K
# 3    $111K-$181K
# 4    $111K-$181K
# Name: filter_salary, dtype: object

# %%
filter_2=[]
for i in range(0,3909):
    output=data_scientist["filter_salary"][i].replace('K',"")
    filter_2.append(output)

# %%
filter_2
# Out:
# ['$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$111-$181 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
#  '$120-$140 ',
# ...

# %%
data_scientist["filter_salary"]=filter_2
data_scientist["filter_salary"].head()
# Out:
# 0    $111-$181
# 1    $111-$181
# 2    $111-$181
# 3    $111-$181
# 4    $111-$181
# Name: filter_salary, dtype: object

# %%
filter_3=[]
for i in range(0,3909):
    output=data_scientist["filter_salary"][i].replace('$',"")
    filter_3.append(output)

# %%
filter_3[:5]
# Out:
# ['111-181 ', '111-181 ', '111-181 ', '111-181 ', '111-181 ']

# %%
data_scientist["filter_salary"]=filter_3
data_scientist["filter_salary"].head()
# Out:
# 0    111-181
# 1    111-181
# 2    111-181
# 3    111-181
# 4    111-181
# Name: filter_salary, dtype: object

# %%
low=[]
high=[]
for i in range(0,3909):
    output=data_scientist["filter_salary"][i].split('-',1)
    low.append(output[0])
    high.append(output[1])

# %%
low[:5]
# Out:
# ['111', '111', '111', '111', '111']

# %%
high[:5]
# Out:
# ['181 ', '181 ', '181 ', '181 ', '181 ']

# %%
data_scientist["low"]=low
data_scientist["high"]=high

# %%
data_scientist.head()
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
#
# ...
